# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("C:\\Users\\EECS\\Downloads\\ml-latest-small\\ml-latest-small\\movies.csv")
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
links = pd.read_csv("C:\\Users\\EECS\\Downloads\\ml-latest-small\\ml-latest-small\\links.csv")
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# 5           6   113277     949.0
# 6           7   114319   11860.0
# 7           8   112302   45325.0
# 8           9   114576    9091.0
# 9          10   113189     710.0
# 10         11   112346    9087.0
# 11         12   112896   12110.0
# 12         13   112453   21032.0
# 13         14   113987   10858.0
# 14         15   112760    1408.0
# 15         16   112641     524.0
# 16         17   114388    4584.0
# 17         18   113101       5.0
# 18         19   112281    9273.0
# 19         20   113845   11517.0
# 20         21   113161    8012.0
# 21         22   112722    1710.0
# 22         23   112401    9691.0
# 23         24   114168   12665.0
# 24         25   113627     451.0
# 25         26   114057   16420.0
# 26         27   114011    9263.0
# ...

# %%
ratings = pd.read_csv("C:\\Users\\EECS\\Downloads\\ml-latest-small\\ml-latest-small\\ratings.csv")
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
dataFrame = pd.DataFrame()
dataFrame['number_of_rating'] = ratings.groupby('movieId')['rating'].count()
dataFrame
# Out:
#          number_of_rating
# movieId
# 1                     215
# 2                     110
# 3                      52
# 4                       7
# 5                      49
# 6                     102
# 7                      54
# 8                       8
# 9                      16
# 10                    132
# 11                     70
# 12                     19
# 13                      8
# 14                     18
# 15                     13
# 16                     82
# 17                     67
# 18                     20
# 19                     88
# 20                     15
# 21                     89
# 22                     36
# 23                     16
# 24                     28
# 25                     76
# 26                     13
# 27                      9
# 28                     11
# 29                     38
# 30                      3
# ...                   ...
# 188189                  1
# 188301                  3
# 188675                  1
# ...

# %%
matrixRatingTable = ratings.pivot_table(index = 'userId', columns = 'movieId', values = 'rating')
matrixRatingTable
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6           NaN     4.0     5.0     3.0     5.0     4.0     4.0     3.0
# 7           4.5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 8           NaN     4.0     NaN     NaN     NaN     NaN     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 11          NaN     NaN     NaN     NaN     NaN     5.0     NaN     NaN
# 12          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
def movie_rec():
    movie = input("What is the movieId to the movie that you like?: ")
    movie = int(movie)
    movie_user_ratings = matrixRatingTable[movie]
    similar_to_movie = matrixRatingTable.corrwith(movie_user_ratings)
    corr_to_movies = pd.DataFrame(similar_to_movie, columns = ['correlation'])
    corr_to_movies['number_of_rating'] = (dataFrame['number_of_rating'])
    corr_to_movies['movie title'] = (movies['title'])
    corr_to_movies.drop(corr_to_movies[corr_to_movies['number_of_rating'] < 150].index, inplace=True)
    corr_to_movies.sort_values(by='correlation', ascending = False, inplace = True)
    #reindex(corr_to_movies['number_of_rating'].sort_values(0, ascending = False).index)
    print(corr_to_movies.head(6))

# %%
movie_rec()
# Out:
# What is the movieId to the movie that you like?: 2762
# C:\Users\EECS\Anaconda3.2\lib\site-packages\numpy\lib\function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\EECS\Anaconda3.2\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#          correlation  number_of_rating  \
# movieId
# 2762        1.000000               179
# 2028        0.533893               188
# 2959        0.423401               218
# 4226        0.372692               159
# 3578        0.357149               170
# 2571        0.348213               278
#
#                                                movie title
# movieId
# 2762               Brother from Another Planet, The (1984)
# 2028           South Park: Bigger, Longer and Uncut (1999)
# 2959                                   Billy Elliot (2000)
# 4226                                        Zapped! (1982)
# ...

# %%
#356 - Forrest Gump (1994)
#318 - Shawshank Redemption, The (1994)
#593 - Silence of the Lambs, The (1991)
#480 - 
#110 - 
#589 -
#527 - 
#2959 - 
#1 - 
#1196 - 
#2858 - 
#50 - 
#47 - 
#780 - 
#150 - 
#1198 - 
#4993 - 
#1210 -
#858 - 
#457 - 
#592 - 
#2028 - 
#5952 - 
#7153 - 
#588 - 
#608 - 
#2762 -
